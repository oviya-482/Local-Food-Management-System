# %%
import pandas as pd

# %%
import os

# %%
df = pd.read_csv("../Data/bakery.csv")
df
# Out:
#      data-product-id                                  data-product-name  \
# 0             872615                         Mr Kipling Viennese Whirls
# 1              56312                          Mr Kipling French Fancies
# 2             684311                          Mr Kipling 8 Angel Slices
# 3             540706                     Waitrose 4 Brioche Burger Buns
# 4             783454     Hovis Seed Sensations Multiseeded Sliced Bread
# ..               ...                                                ...
# 480           384230                         Galaxy Chocolate Cake Bars
# 481           376437                                 25cm Football Cake
# 482           374515  Waitrose Ready To Bake 4 All Butter Cinnamon S...
# 483           297903             Dr. Oetker Old School Cake Mix Vanilla
# 484            77133                 Cohens Bakery Buckingham Rye Bread
#
#     data-product-type  data-product-on-offer  data-product-index  \
# ...

# %%
 # How many rows and columns
 df.shape
# Out:
# (485, 13)

# %%
#list all the columns 
df.columns
# Out:
# Index(['data-product-id', 'data-product-name', 'data-product-type',
#        'data-product-on-offer', 'data-product-index', 'image-url',
#        'product-page', 'product-name', 'product-size', 'item-price',
#        'price-per-unit', 'offer-description', 'category'],
#       dtype='object')

# %%
#view subset of columns
df[['product-name', 'item-price', 'category']]
# Out:
#                                           product-name item-price category
# 0                           Mr Kipling Viennese Whirls      £1.98   Bakery
# 1                            Mr Kipling French Fancies      £2.36   Bakery
# 2                            Mr Kipling 8 Angel Slices      £2.96   Bakery
# 3                       Waitrose 4 Brioche Burger Buns      £1.31   Bakery
# 4       Hovis Seed Sensations Multiseeded Sliced Bread      £1.90   Bakery
# ..                                                 ...        ...      ...
# 480                         Galaxy Chocolate Cake Bars      £2.25   Bakery
# 481                                 25cm Football Cake     £30.00   Bakery
# 482  Waitrose Ready To Bake 4 All Butter Cinnamon S...      £2.60   Bakery
# 483             Dr. Oetker Old School Cake Mix Vanilla      £3.00   Bakery
# 484                 Cohens Bakery Buckingham Rye Bread      £2.10   Bakery
#
# [485 rows x 3 columns]

# %%
#top 5 rows
df.head(5)
# Out:
#    data-product-id                               data-product-name  \
# 0           872615                      Mr Kipling Viennese Whirls
# 1            56312                       Mr Kipling French Fancies
# 2           684311                       Mr Kipling 8 Angel Slices
# 3           540706                  Waitrose 4 Brioche Burger Buns
# 4           783454  Hovis Seed Sensations Multiseeded Sliced Bread
#
#   data-product-type  data-product-on-offer  data-product-index  \
# 0                 G                   True                 246
# 1                 G                   True                 161
# 2                 G                   True                 277
# 3                 G                   True                   4
# 4                 G                  False                   5
#
#                                            image-url  \
# 0  https://ecom-su-static-prod.wtrecom.com/images...
# 1  https://ecom-su-static-prod.wtrecom.com/images...
# ...

# %%
df.iloc[0]
# Out:
# data-product-id                                                     872615
# data-product-name                               Mr Kipling Viennese Whirls
# data-product-type                                                        G
# data-product-on-offer                                                 True
# data-product-index                                                     246
# image-url                https://ecom-su-static-prod.wtrecom.com/images...
# product-page             https://www.waitrose.com/ecom/products/mr-kipl...
# product-name                                    Mr Kipling Viennese Whirls
# product-size                                                            6s
# item-price                                                           £1.98
# price-per-unit                                                    33p each
# offer-description                                       25% Off. Was £2.65
# ...

# %%
df.iloc[0,2]
# Out:
# 'G'

# %%
df.query('`product-size` == "800g"')
# Out:
#      data-product-id                               data-product-name  \
# 4             783454  Hovis Seed Sensations Multiseeded Sliced Bread
# 6              75319         Waitrose Super Soft White Medium Sliced
# 10            837159               Jacksons Multigrain Brown Bloomer
# 11            818881        Waitrose Soft White Toastie Thick Sliced
# 12            563526                     Jacksons Soft White Bloomer
# 17             55041      Waitrose Wholemeal Farmhouse Medium Sliced
# 20            520256    Black Sheep Craft Bakery White Tiger Bloomer
# 22            463468                 Waitrose Multi-Seeded Farmhouse
# 29             84740          Hovis Best of Both Medium Sliced Bread
# 31             55047             Hovis Wholemeal Medium Sliced Bread
# 34              3062      Hovis Soft White Medium Sliced White Bread
# 52            827079                      Jacksons Multiseed Bloomer
# 56             55416      Hovis Original Granary Medium Sliced Bread
# ...

# %%
df.query('`product-size` == "800g"')[['product-name', 'item-price', 'category']]
# Out:
#                                        product-name item-price category
# 4    Hovis Seed Sensations Multiseeded Sliced Bread      £1.90   Bakery
# 6           Waitrose Super Soft White Medium Sliced      £1.00   Bakery
# 10                Jacksons Multigrain Brown Bloomer      £1.85   Bakery
# 11         Waitrose Soft White Toastie Thick Sliced      £1.00   Bakery
# 12                      Jacksons Soft White Bloomer      £1.85   Bakery
# 17       Waitrose Wholemeal Farmhouse Medium Sliced      £1.45   Bakery
# 20     Black Sheep Craft Bakery White Tiger Bloomer      £2.00   Bakery
# 22                  Waitrose Multi-Seeded Farmhouse      £1.55   Bakery
# 29           Hovis Best of Both Medium Sliced Bread      £1.35   Bakery
# 31              Hovis Wholemeal Medium Sliced Bread      £1.45   Bakery
# 34       Hovis Soft White Medium Sliced White Bread      £1.45   Bakery
# 52                       Jacksons Multiseed Bloomer      £1.85   Bakery
# ...

# %%
df[df['product-name'].str.contains('Sliced')][['product-name', 'item-price', 'category']]
# Out:
#                                        product-name item-price category
# 4    Hovis Seed Sensations Multiseeded Sliced Bread      £1.90   Bakery
# 6           Waitrose Super Soft White Medium Sliced      £1.00   Bakery
# 8               Hovis Wholemeal Medium Sliced Bread      £1.10   Bakery
# 11         Waitrose Soft White Toastie Thick Sliced      £1.00   Bakery
# 17       Waitrose Wholemeal Farmhouse Medium Sliced      £1.45   Bakery
# 23   Hovis Seed Sensations Multiseeded Sliced Bread      £1.20   Bakery
# 29           Hovis Best of Both Medium Sliced Bread      £1.35   Bakery
# 31              Hovis Wholemeal Medium Sliced Bread      £1.45   Bakery
# 34       Hovis Soft White Medium Sliced White Bread      £1.45   Bakery
# 54        Hovis Original Granary Thick Sliced Bread      £1.25   Bakery
# 56       Hovis Original Granary Medium Sliced Bread      £1.90   Bakery
# 61                   Hovis 1886 Seeded Sliced Bread      £1.50   Bakery
# ...

# %%
df[(df['product-name'].str.contains('Bread')) & (df['product-size'] == '800g')]
# Out:
#      data-product-id                               data-product-name  \
# 4             783454  Hovis Seed Sensations Multiseeded Sliced Bread
# 29             84740          Hovis Best of Both Medium Sliced Bread
# 31             55047             Hovis Wholemeal Medium Sliced Bread
# 34              3062      Hovis Soft White Medium Sliced White Bread
# 56             55416      Hovis Original Granary Medium Sliced Bread
# 64             90605       Hovis Soft White Thick Sliced White Bread
# 79             55051         Essential Wholemeal Medium Sliced Bread
# 83             91814              Hovis Wholemeal Thick Sliced Bread
# 85             35513                    Vogel's Soya & Linseed Bread
# 104            54266            Hovis Granary Wholemeal Sliced Bread
# 109            55428              Vogel's Original Mixed Grain Bread
# 178            55018             Essential White Medium Sliced Bread
#
#     data-product-type  data-product-on-offer  data-product-index  \
# ...
