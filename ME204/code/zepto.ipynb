# %%
import requests
from scrapy import Selector
import pandas as pd

# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.41.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: certifi>=2026.1.4 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from selenium) (2026.1.4)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Using cached trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.6.3)
# Collecting websocket-client<2.0,>=1.8.0 (from selenium)
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: attrs>=23.2.0 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio<1.0,>=0.31.0->selenium)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: cffi>=1.14 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (3.0)
# Collecting h11<1,>=0.16.0 (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Using cached selenium-4.41.0-py3-none-any.whl (9.5 MB)
# Using cached trio-0.33.0-py3-none-any.whl (510 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wsproto-1.3.2-py3-none-any.whl (24 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, websocket-client, sniffio, pysocks, outcome, h11, wsproto, trio, trio-websocket, selenium
#
#    ---- -----------------------------------  1/10 [websocket-client]
#    ---- -----------------------------------  1/10 [websocket-client]
#    -------------------- -------------------  5/10 [h11]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ---------------------------- -----------  7/10 [trio]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ------------------------------------ ---  9/10 [selenium]
#    ---------------------------------------- 10/10 [selenium]
#
# Successfully installed h11-0.16.0 outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.41.0 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.33.0 trio-websocket-0.12.2 websocket-client-1.9.0 wsproto-1.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from webdriver_manager) (2.32.5)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: packaging in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from webdriver_manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->webdriver_manager) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->webdriver_manager) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->webdriver_manager) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->webdriver_manager) (2026.1.4)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, webdriver_manager
#
#    -------------------- ------------------- 1/2 [webdriver_manager]
#    ---------------------------------------- 2/2 [webdriver_manager]
#
# Successfully installed python-dotenv-1.2.2 webdriver_manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
# Set up Chrome options for Selenium
#Dynamic JavaScript-based websites cannot be scraped using 
# basic HTTP requests alone; browser automation tools like Selenium are required.
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")  # Headless mode is used to run the browser without a graphical interface to improve performance.
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")

# %% [markdown]
# #### The ChromeDriverManager is used to automatically download and manage the compatible ChromeDriver version, and the Service object initializes the driver for Selenium.

# %%
service = Service(ChromeDriverManager().install())

# %%
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# #### The driver.get() method is used to navigate the automated browser to the specified URL.

# %%
url = "https://www.zepto.com/?srsltid=AfmBOorZ3M-yGpUiz1PDmuqaGltonRG5K673_NSCwwQILNWTt_LgZden"
driver.get(url)

# %%
#### driver.page_source retrieves the complete HTML content of the dynamically rendered webpage.

# %%
page_source = driver.page_source

# %%
sel = Selector(text=page_source)

# %% [markdown]
# #### This list contains pagination URLs to scrape product data from multiple pages instead of only the first page, ensuring comprehensive data collection.

# %%
###Link of urls
links = ["https://www.zepto.com/?srsltid=AfmBOooJu_rixVR604AFCAZh2b4Ymt_EM5oABgAQaE8bwuxu7lKw4b5J",

]
