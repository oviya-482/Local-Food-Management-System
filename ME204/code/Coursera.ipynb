# %%
import requests                         # for sending HTTP requests

from tqdm.notebook import tqdm, trange  # for progress bars

from scrapy import Selector             # for parsing HTML content

# %%
coursera_url = "https://www.coursera.org/courseraplus"

# %%
coursera_url
# Out:
# 'https://www.coursera.org/courseraplus'

# %%
response = requests.get(coursera_url)

# %%
response
# Out:
# <Response [200]>

# %%
sel = Selector(text=requests.get(coursera_url).content)
