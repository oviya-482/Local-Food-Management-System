# %% [markdown]
# LSE Data Science Institute | ME204 (2023/24) | Week 03 Day 01
#
# # 🗓️ Week 03 – Day 01: Intro to Databases and SQL
#
#
# <span style="display: inline-block; padding: 0 10px; font-size: 1.15em;line-height: 1.5em; white-space: nowrap; border: 1px solid #3995ba; border-radius: .5em; color: #fcfcfc; background-color: #3995ba; vertical-align: middle;font-weight: 600 !important;">MORNING NOTEBOOK</span>
#
# **DATE:** 22 July 2024
#
# **AUTHOR:** Alex Soldatkin & Dr [Jon Cardoso-Silva](https://jonjoncardoso.github.io)
#
# -----

# %% [markdown]
# # ⚙️ Setup
#
# You can use your `base` environment or create a new one for this notebook.
#
# These are the libraries you need to install:
#
# <div style="width:60%;font-size:0.85em">
#
# ```bash
# pip install pandas numpy lets-plot numerize tqdm sqlalchemy jupysql
# ```
#
# 💡 **NOTE**: There are a few new ones today: the [`jupysql`](https://jupysql.ploomber.io/en/latest/intro.html) and [`sqlalchemy`](https://www.sqlalchemy.org/) packages.
#
# </div>

# %% [markdown]
# **IMPORTS:**

# %%
pip install sqlite3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
import os
import sqlite3


import numpy as np
import pandas as pd

from tqdm.notebook import tqdm, trange
tqdm.pandas()

# %% [markdown]
# **CONSTANTS:**

# %%
# Adjust it according to your data folder
DATA_FOLDER = os.path.join('../data/')

WAITROSE_FOLDER = os.path.join(DATA_FOLDER, 'waitrose')

# %%
# %load_ext sql
# %config SqlMagic.autocommit=True # for engines that do not support autommit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#       2 get_ipython().run_line_magic('config', 'SqlMagic.autocommit=True # for engines that do not support autommit')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\magics\extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\extensions.py:62, in ExtensionManager.load_extension(self, module_str)
#      55 """Load an IPython extension by its module name.
#      56
#      57 Returns the string "already loaded" if the extension is already loaded,
#      58 "no load function" if the module doesn't have a load_ipython_extension
#      59 function, or None if it succeeded.
#      60 """
#      61 try:
# ---> 62     return self._load_extension(module_str)
#      63 except ModuleNotFoundError:
#      64     if module_str in BUILTINS_EXTS:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\extensions.py:77, in ExtensionManager._load_extension(self, module_str)
#      75 with self.shell.builtin_trap:
#      76     if module_str not in sys.modules:
# ---> 77         mod = import_module(module_str)
#      78     mod = sys.modules[module_str]
#      79     if self._call_load_ipython_extension(mod):
#
# File c:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sql'

# %% [markdown]
# **READ THE RAW DATA**
#
# Read the bunch of CSV files we got from scraping the Waitrose website.

# %%
# Run this very long and ugly cell to get the full dataset
all_files = [os.path.join(WAITROSE_FOLDER,  file) for file in os.listdir(WAITROSE_FOLDER) 
             if file.endswith('.csv')]

# Reads every individual file and concatenates them into a single DataFrame using pandas concat
df = pd.concat((pd.read_csv(file) for file in all_files))

df = df.drop_duplicates()

df = df.drop(columns=['data-product-name'])
df = (
    df.rename(columns={
        'data-product-type': 'type',
        'data-product-index': 'index',
        'data-product-id': 'id',
        'data-product-on-offer': 'on-offer',
        'product-page': 'page',
        'product-name': 'name',
        'product-size': 'size',
    })
)

def clean_item_price(item_price: str):
    """
    Cleans the item price string by performing necessary transformations.

    Parameters:
    item_price (str): The item price as a string.

    Returns:
    float: The cleaned item price.
    """
    if pd.isna(item_price):
        return np.nan
    
    item_price = item_price.replace(' each est.', '')
    
   
    if '-' in item_price:
        item_prices = item_price.replace('£', '').split('-')
        item_prices = [float(price) for price in item_prices]
        item_price = np.mean(item_prices)
    else:
        if '£' in item_price:
            item_price = item_price.replace('£', '')
            item_price = float(item_price)
        elif 'p' in item_price:
            item_price = item_price.replace('p', '')
            item_price = float('0.' + item_price)
    
    return float(item_price)

df['id'] = df['id'].astype('int32')
df['cleaned-item-price'] = df['item-price'].apply(lambda price: clean_item_price(price))

selected_rows = df['item-price'].astype(str).str.contains('-')

# The 'size' column of the selected rows all have the same kind of format: (2.2kg-2.8kg).
df.loc[selected_rows, 'size'] = df.loc[selected_rows, 'size'].str.split('-').str[0].str.replace('(', '')

df['item-price'] = df['cleaned-item-price']
df.drop(columns=['cleaned-item-price', 'index'], inplace=True)

df
# Out:
#           id type  on-offer  \
# 0     525635    G     False
# 1     557746    G     False
# 2      32062    G     False
# 3     767801    G     False
# 4     514054    G     False
# ...      ...  ...       ...
# 1589   18427    G     False
# 1590   11606    G     False
# 1591    6903    G     False
# 1592    6125    G     False
# 1593  707668    W     False
#
#                                               image-url  \
# 0     https://ecom-su-static-prod.wtrecom.com/images...
# 1     https://ecom-su-static-prod.wtrecom.com/images...
# 2     https://ecom-su-static-prod.wtrecom.com/images...
# 3     https://ecom-su-static-prod.wtrecom.com/images...
# 4     https://ecom-su-static-prod.wtrecom.com/images...
# ...                                                 ...
# 1589  https://ecom-su-static-prod.wtrecom.com/images...
# 1590  https://ecom-su-static-prod.wtrecom.com/images...
# 1591  https://ecom-su-static-prod.wtrecom.com/images...
# 1592  https://ecom-su-static-prod.wtrecom.com/images...
# 1593  https://ecom-su-static-prod.wtrecom.com/images...
#
#                                                    page  \
# 0     https://www.waitrose.com/ecom/products/organix...
# 1     https://www.waitrose.com/ecom/products/organix...
# 2     https://www.waitrose.com/ecom/products/aptamil...
# 3     https://www.waitrose.com/ecom/products/essenti...
# 4     https://www.waitrose.com/ecom/products/organix...
# ...                                                 ...
# 1589  https://www.waitrose.com/ecom/products/duchy-o...
# 1590  https://www.waitrose.com/ecom/products/cooks-i...
# 1591  https://www.waitrose.com/ecom/products/no-1-ba...
# 1592  https://www.waitrose.com/ecom/products/cooks-i...
# 1593  https://www.waitrose.com/ecom/products/duchy-o...
#
#                                                    name  \
# 0              Organix Raspberry & Apple Soft Oaty Bars
# 1                         Organix Carrot Cake Oaty Bars
# 2                              Aptamil 2 Follow On Milk
# 3                                  Essential Baby Wipes
# 4                              Organix Apple Rice Cakes
# ...                                                 ...
# 1589                Duchy Organic British Lamb Half Leg
# 1590                         Cooks' Ingredients Wok Oil
# 1591  No. 1 Badoz Vacherin Du Haut-Doubs AOP French ...
# 1592                  Cooks' Ingredients White Marzipan
# 1593              Duchy Organic Pinot Grigio Bag in Box
#
#                        size  item-price price-per-unit offer-description  \
# 0                     6x23g        3.15     £2.29/100g               NaN
# 1                     6x23g        3.15     £2.29/100g               NaN
# 2                      800g       13.50      £16.88/kg               NaN
# 3                       80s        0.95      1.2p each               NaN
# 4                       40g        1.60        £4/100g               NaN
# ...                     ...         ...            ...               ...
# 1589  Typical weight 0.94kg       24.31      £26.00/kg               NaN
# 1590                  250ml        2.40      96p/100ml               NaN
# 1591                   350g       10.00      £28.58/kg               NaN
# 1592                   500g        2.50          £5/kg               NaN
# 1593                  2.25L       21.49     £7.17/75cl               NaN
#
#                   category
# 0     Baby, Child & Parent
# 1     Baby, Child & Parent
# 2     Baby, Child & Parent
# 3     Baby, Child & Parent
# 4     Baby, Child & Parent
# ...                    ...
# 1589       Waitrose Brands
# 1590       Waitrose Brands
# 1591       Waitrose Brands
# 1592       Waitrose Brands
# 1593       Waitrose Brands
#
# [25378 rows x 11 columns]

# %% [markdown]
# **CONNECT TO THE DATABASE**

# %%
conn = sqlite3.connect(os.path.join(DATA_FOLDER, 'supermarket.db'))

# %% [markdown]
# ## SOLUTION 01: NO FORMAL KEY CONSTRAINTS (easyer to implement but less ideal)
#
#
# <div style="width:400px;height:260px;border-radius:1em;margin:0.5%;padding:1%;background-color:#fafafa">
#
# <h2>💡 Read this!</h2>
#
# In this solution, we will create multiple tables to help us exercise linking them together with `pandas` later. I will not use primary or foreign keys. Instead, I will derive the separate data frames from the main one, making sure that there are no duplicates left, before I dump them into the database.
#
# I believe this might be easier for those who are just starting with SQL, with the caveat that <span style="color:red"> this is not the best practice for databases</span>. Ideally, you want to enforce constraints (primary and foreign keys) to ensure data integrity -- and we can't get that with this approach.
# </div>

# %% [markdown]
# ### Table 01: `products`
#
# <details style="color:transparent;background-color:transparent;height:0px">
#
# It turns out that IDs are truly unique, we do not need (id, name, size) like we've been doing in the past. This saves us a lot of time and effort. We can just use the `id` as the primary key for the `products` table.
#
# To confirm that:
#
# ```python
# (
#     df
#      .groupby(['id'])
#      .apply(lambda x: pd.Series({'num_unique_pages': x['page'].nunique()}))
#      .sort_values('num_unique_pages', ascending=False)
#      .query('num_unique_pages > 1')
# )
# ````
#
# </details>
#
#
# We know that we **want** to exercise the linking of tables, so we will not include the `category` column in this table. We will create a separate table for that. That also applies for the information about prices and offers.
#
# This leaves us with the following columns for the `products` table:
#
# - `id` (int): the unique identifier for the product (as determined by Waitrose)
# - `name` (str): the name of the product
# - `size` (str): the size of the product
# - `page` (str): the URL of the product's page on the Waitrose website
# - `image-url` (str): the URL of the product's image
# - `type` (str): the type of the product (which, to be honest, I don't know what it means)
#
# 👉 **These are all the attributes that are specific to the product itself and not to its price or offer or category.**
#
# Let's build the dataframe for the `products` table.

# %%
selected_columns = ['id', 'name', 'size', 'page', 'image-url', 'type']

products = df[selected_columns].copy().drop_duplicates()

print(f"While the original dataset has {len(df)} rows, the cleaned dataset has {len(products)} rows, which means that {len(df) - len(products)} rows were removed.")
# Out:
# While the original dataset has 25378 rows, the cleaned dataset has 16065 rows, which means that 9313 rows were removed.

# %% [markdown]
# What is in the `products` dataframe?

# %%
products
# Out:
#           id                                               name  \
# 0     525635           Organix Raspberry & Apple Soft Oaty Bars
# 1     557746                      Organix Carrot Cake Oaty Bars
# 2      32062                           Aptamil 2 Follow On Milk
# 3     767801                               Essential Baby Wipes
# 4     514054                           Organix Apple Rice Cakes
# ...      ...                                                ...
# 35     85201                                    Essential Leeks
# 1098  461285      Cooks' Ingredients Chargrilled Peppers in Oil
# 1293  539814  Cooks' Ingredients Frozen Herby Chimichurri Po...
# 1330  589503               Cooks' Ingredients Artichokes in Oil
# 1438  723407   Cooks' Ingredients Frozen Stir Fry Vegetable Mix
#
#                        size  \
# 0                     6x23g
# 1                     6x23g
# 2                      800g
# 3                       80s
# 4                       40g
# ...                     ...
# 35    Typical weight 0.21kg
# 1098           drained 170g
# 1293                   350g
# 1330           drained 160g
# 1438                   400g
#
#                                                    page  \
# 0     https://www.waitrose.com/ecom/products/organix...
# 1     https://www.waitrose.com/ecom/products/organix...
# 2     https://www.waitrose.com/ecom/products/aptamil...
# 3     https://www.waitrose.com/ecom/products/essenti...
# 4     https://www.waitrose.com/ecom/products/organix...
# ...                                                 ...
# 35    https://www.waitrose.com/ecom/products/essenti...
# 1098  https://www.waitrose.com/ecom/products/cooks-i...
# 1293  https://www.waitrose.com/ecom/products/cooks-i...
# 1330  https://www.waitrose.com/ecom/products/cooks-i...
# 1438  https://www.waitrose.com/ecom/products/cooks-i...
#
#                                               image-url type
# 0     https://ecom-su-static-prod.wtrecom.com/images...    G
# 1     https://ecom-su-static-prod.wtrecom.com/images...    G
# 2     https://ecom-su-static-prod.wtrecom.com/images...    G
# 3     https://ecom-su-static-prod.wtrecom.com/images...    G
# 4     https://ecom-su-static-prod.wtrecom.com/images...    G
# ...                                                 ...  ...
# 35    https://ecom-su-static-prod.wtrecom.com/images...    G
# 1098  https://ecom-su-static-prod.wtrecom.com/images...    G
# 1293  https://ecom-su-static-prod.wtrecom.com/images...    G
# 1330  https://ecom-su-static-prod.wtrecom.com/images...    G
# 1438  https://ecom-su-static-prod.wtrecom.com/images...    G
#
# [16065 rows x 6 columns]

# %% [markdown]
# Let's save it to the database.

# %%
products.to_sql('products', conn, if_exists='replace', index=False)
# Out:
# 16065

# %% [markdown]
# Test that it worked:

# %%
pd.read_sql('SELECT COUNT(*) AS total_num_products FROM products', conn)
# Out:
#    total_num_products
# 0               16065

# %%
# See what the table looks like, get just the first 5 rows
pd.read_sql('SELECT * FROM products LIMIT 5', conn)
# Out:
#        id                                      name   size  \
# 0  525635  Organix Raspberry & Apple Soft Oaty Bars  6x23g
# 1  557746             Organix Carrot Cake Oaty Bars  6x23g
# 2   32062                  Aptamil 2 Follow On Milk   800g
# 3  767801                      Essential Baby Wipes    80s
# 4  514054                  Organix Apple Rice Cakes    40g
#
#                                                 page  \
# 0  https://www.waitrose.com/ecom/products/organix...
# 1  https://www.waitrose.com/ecom/products/organix...
# 2  https://www.waitrose.com/ecom/products/aptamil...
# 3  https://www.waitrose.com/ecom/products/essenti...
# 4  https://www.waitrose.com/ecom/products/organix...
#
#                                            image-url type
# 0  https://ecom-su-static-prod.wtrecom.com/images...    G
# 1  https://ecom-su-static-prod.wtrecom.com/images...    G
# 2  https://ecom-su-static-prod.wtrecom.com/images...    G
# 3  https://ecom-su-static-prod.wtrecom.com/images...    G
# 4  https://ecom-su-static-prod.wtrecom.com/images...    G

# %% [markdown]
# ### Table 2: `categories` (DIFFICULT BUT GOOD LEARNING OPPORTUNITY)
#
# Previously, I showed you an example where we created a very simple `categories` table with only two columns: `id` and `name`. This is common practice in databases when you need to keep track of additional information about the categories. Say, for example, you want to keep track of the number of products in each category, when they started being sold, when they became inactive, etc. In that scenario, I would ideally create a third table, just to map `category_id` to `product_id`. This is also called a [**many-to-many relationship**](https://www.geeksforgeeks.org/relationships-in-sql-one-to-one-one-to-many-many-to-many/).
#
# Since we don't have additional info on the categories themselves, I will simplify things and create just one table that relates to `categories`. In this table, each product can be associated with multiple categories. This is a [**one-to-many relationship**](https://www.geeksforgeeks.org/relationships-in-sql-one-to-one-one-to-many-many-to-many/).
#
# This table will have the following columns:
#
# - `product_id` (int): the unique identifier for the product
# - `category_name` (int): the name of the category
#
# That's it! By moving it to a separate table, we keep the `products` table free of duplicates and make it easier to update the categories for a product.
#
# Let's write the code to create this table:

# %%
# This is how the table looks like
categories = (
    df[['id', 'category']].drop_duplicates()
    .rename(columns={'category': 'name', 'id': 'product_id'})
)

# %% [markdown]
# Time to save it:

# %%
categories.to_sql('categories', conn, if_exists='replace', index=False)
# Out:
# 25377

# %% [markdown]
# **Test that it works**

# %%
pd.read_sql('SELECT * FROM categories LIMIT 5', conn)
# Out:
#    product_id       name
# 0      497633  Household
# 1      627645  Household
# 2      475915  Household
# 3       28863  Household
# 4       22482  Household

# %% [markdown]
# #### What if I want to get the categories of a product under this new schema?

# %%
# We select the products and join them with the categories table to get the category names
pd.read_sql(
'''
SELECT
    p.*,
    c.name AS category
FROM
    products p
LEFT JOIN
    categories c
ON
    p.id = c.product_id
LIMIT 5
''', conn)
# Out:
#        id                                      name   size  \
# 0  525635  Organix Raspberry & Apple Soft Oaty Bars  6x23g
# 1  557746             Organix Carrot Cake Oaty Bars  6x23g
# 2   32062                  Aptamil 2 Follow On Milk   800g
# 3  767801                      Essential Baby Wipes    80s
# 4  767801                      Essential Baby Wipes    80s
#
#                                                 page  \
# 0  https://www.waitrose.com/ecom/products/organix...
# 1  https://www.waitrose.com/ecom/products/organix...
# 2  https://www.waitrose.com/ecom/products/aptamil...
# 3  https://www.waitrose.com/ecom/products/essenti...
# 4  https://www.waitrose.com/ecom/products/essenti...
#
#                                            image-url type  \
# 0  https://ecom-su-static-prod.wtrecom.com/images...    G
# 1  https://ecom-su-static-prod.wtrecom.com/images...    G
# 2  https://ecom-su-static-prod.wtrecom.com/images...    G
# 3  https://ecom-su-static-prod.wtrecom.com/images...    G
# 4  https://ecom-su-static-prod.wtrecom.com/images...    G
#
#                category
# 0  Baby, Child & Parent
# 1  Baby, Child & Parent
# 2  Baby, Child & Parent
# 3  Baby, Child & Parent
# 4                Summer

# %% [markdown]
# ☝️ Notice how the products appear multiple times if they have more than one category. This is the expected behavior, as we are linking the two tables together with a simple JOIN operation.
#
# **Here's an alternative way that preserves the unique products:**

# %%
# We group by the `product_id` and use GROUP_CONCAT to concatenate all the category names into a single string
pd.read_sql(
'''
SELECT
    p.*,
    GROUP_CONCAT(c.name) AS categories
FROM
    products p
LEFT JOIN
    categories c
ON
    p.id = c.product_id
GROUP BY
    p.id
LIMIT 5
''', conn)
# Out:
#      id                                               name  size  \
# 0  1023       Taylors of Harrogate Yorkshire Gold 160 Bags  500g
# 1  1029            Nestlé Box Bowls Variety 6 Portion Pack  210g
# 2  1048  Kellogg's Corn Flakes Breakfast Cereal Large Pack  670g
# 3  1051  Kellogg's Crunchy Nut Breakfast Cereal Large Pack  840g
# 4  1052             Kellogg's Crunchy Nut Breakfast Cereal  460g
#
#                                                 page  \
# 0  https://www.waitrose.com/ecom/products/taylors...
# 1  https://www.waitrose.com/ecom/products/nestle-...
# 2  https://www.waitrose.com/ecom/products/kellogg...
# 3  https://www.waitrose.com/ecom/products/kellogg...
# 4  https://www.waitrose.com/ecom/products/kellogg...
#
#                                            image-url type  \
# 0  https://ecom-su-static-prod.wtrecom.com/images...    G
# 1  https://ecom-su-static-prod.wtrecom.com/images...    G
# 2  https://ecom-su-static-prod.wtrecom.com/images...    G
# 3  https://ecom-su-static-prod.wtrecom.com/images...    G
# 4  https://ecom-su-static-prod.wtrecom.com/images...    G
#
#                           categories
# 0          Tea, Coffee & Soft Drinks
# 1                      Food Cupboard
# 2  Dietary & Lifestyle,Food Cupboard
# 3  Dietary & Lifestyle,Food Cupboard
# 4  Dietary & Lifestyle,Food Cupboard

# %% [markdown]
# ### Table 3: `prices`
#
# The `prices` table will have the following columns:
#
# - `product_id` (int): the unique identifier for the product
# - `item-price` (float): the price of the product
# - `price-per-unit` (float): the price per unit of the product
#
# The process is very similar to what we did for the `categories` table:

# %%
prices = (
    df[['id', 'item-price', 'price-per-unit']].drop_duplicates()
    .sort_values('id')
    .rename(columns={'id': 'product_id'})
)
prices.head()
# Out:
#       product_id  item-price price-per-unit
# 314         1023        7.10     £1.42/100g
# 2403        1029        2.30     £1.10/100g
# 513         1048        2.75       41p/100g
# 794         1051        5.00     59.5p/100g
# 805         1052        2.75     59.8p/100g

# %% [markdown]
# Save it:

# %%
prices.to_sql('prices', conn, if_exists='replace', index=False)
# Out:
# 16065

# %% [markdown]
# Test that the table was created correctly

# %%
pd.read_sql('SELECT * FROM prices LIMIT 5', conn)
# Out:
#    product_id  item-price price-per-unit
# 0        1023        7.10     £1.42/100g
# 1        1029        2.30     £1.10/100g
# 2        1048        2.75       41p/100g
# 3        1051        5.00     59.5p/100g
# 4        1052        2.75     59.8p/100g

# %% [markdown]
# For each product in the `products` table, recover their prices and categories.

# %%
pd.read_sql(
'''
SELECT
    p.*,
    pr.*,
    GROUP_CONCAT(DISTINCT c.name) AS categories
FROM
    products p
LEFT JOIN
    prices pr
ON
    p.id = pr.product_id
LEFT JOIN
    categories c
ON
    p.id = c.product_id
GROUP BY p.id
LIMIT 5
''', conn)
# Out:
#      id                                               name  size  \
# 0  1023       Taylors of Harrogate Yorkshire Gold 160 Bags  500g
# 1  1029            Nestlé Box Bowls Variety 6 Portion Pack  210g
# 2  1048  Kellogg's Corn Flakes Breakfast Cereal Large Pack  670g
# 3  1051  Kellogg's Crunchy Nut Breakfast Cereal Large Pack  840g
# 4  1052             Kellogg's Crunchy Nut Breakfast Cereal  460g
#
#                                                 page  \
# 0  https://www.waitrose.com/ecom/products/taylors...
# 1  https://www.waitrose.com/ecom/products/nestle-...
# 2  https://www.waitrose.com/ecom/products/kellogg...
# 3  https://www.waitrose.com/ecom/products/kellogg...
# 4  https://www.waitrose.com/ecom/products/kellogg...
#
#                                            image-url type  product_id  \
# 0  https://ecom-su-static-prod.wtrecom.com/images...    G        1023
# 1  https://ecom-su-static-prod.wtrecom.com/images...    G        1029
# 2  https://ecom-su-static-prod.wtrecom.com/images...    G        1048
# 3  https://ecom-su-static-prod.wtrecom.com/images...    G        1051
# 4  https://ecom-su-static-prod.wtrecom.com/images...    G        1052
#
#    item-price price-per-unit                         categories
# 0        7.10     £1.42/100g          Tea, Coffee & Soft Drinks
# 1        2.30     £1.10/100g                      Food Cupboard
# 2        2.75       41p/100g  Dietary & Lifestyle,Food Cupboard
# 3        5.00     59.5p/100g  Dietary & Lifestyle,Food Cupboard
# 4        2.75     59.8p/100g  Dietary & Lifestyle,Food Cupboard

# %% [markdown]
# ### Table 4: `offers`
#
# The `offers` table will have the following columns:
#
# - `product_id` (int): the unique identifier for the product
# - `offer-description` (str): the offer on the product
#
#
# **⚠️ IMPORTANT**: I don't need to store a `is_on_offer` column in the `products` table. This is redundant information, as I can get this information from the `offers` table. When joining the two tables, I can check if the `description` column is not null.

# %%
offers = (
    df[df['on-offer'] == True][['id', 'offer-description']].drop_duplicates()
    .sort_values('id')
    .rename(columns={'id': 'product_id'})
)
offers
# Out:
#       product_id                 offer-description
# 513         1048               save 45p. Was £3.20
# 805         1052               save 75p. Was £3.50
# 863         1066               save 70p. Was £3.45
# 1316        1138             save £1.30. Was £3.80
# 1248        1182               save 85p. Was £1.85
# ...          ...                               ...
# 2882      988412  Introductory Offer.Will be £6.00
# 3161      990127  Introductory Offer.Will be £3.65
# 3160      995459                          New Line
# 3158      999031  Introductory Offer.Will be £1.20
# 1625      999167  Introductory Offer.Will be £2.00
#
# [4656 rows x 2 columns]

# %% [markdown]
# By filtering to only the products that are on offer, I get fewer rows in the `offers` table, which is good for performance.

# %%
offers.to_sql('offers', conn, if_exists='replace', index=False)
# Out:
# 4656

# %% [markdown]
# To select **only the products that are on offer**, use the `INNER JOIN` operation:

# %%
pd.read_sql(
'''
SELECT
    p.id,
    p.name,
    o.`offer-description`
FROM
    products p
INNER JOIN
    offers o
ON 
    p.id = o.product_id
''', conn
)
# Out:
#           id                                               name  \
# 0     671670                                 Pampers Baby Wipes
# 1     847776                        Ella's Kitchen Puree Prunes
# 2     575652                           Waterwipes Biodegradable
# 3     551725                         Ella's Kitchen Puree Pears
# 4     533572                        Ella's Kitchen Puree Apples
# ...      ...                                                ...
# 4654   70603                Aussie Colour Mate Hair Conditioner
# 4655   57572                         Dove Essential Body Lotion
# 4656   51416                              E45 Itch Relief Cream
# 4657   35386               Simple Kind to Skin Cleansing Lotion
# 4658  539814  Cooks' Ingredients Frozen Herby Chimichurri Po...
#
#                 offer-description
# 0                    Add 2 for £2
# 1                 Add 5 for £4.50
# 2             save 60p. Was £3.10
# 3                 Add 5 for £4.50
# 4                 Add 5 for £4.50
# ...                           ...
# 4654          Save 1/3. Was £4.50
# 4655          Save 1/3. Was £6.10
# 4656         Save 1/3. Was £11.00
# 4657          Save 1/3. Was £3.70
# 4658  Reduced to Clear. Was £3.50
#
# [4659 rows x 3 columns]

# %% [markdown]
# To add a `is-on-offer` column to the `products` table, use the `LEFT JOIN` operation and the `CASE` statement:

# %%
# Add is-on-offer column to the products table if there's no offer for a product, set it to False
pd.read_sql(
'''
SELECT
    p.id,
    p.name,
    o.`offer-description`,
    CASE
        WHEN o.`offer-description` IS NULL THEN False
        ELSE True
    END AS `is-on-offer`
FROM
    products p
LEFT JOIN
    offers o
ON
    p.id = o.product_id
''', conn
)
# Out:
#            id                                               name  \
# 0      525635           Organix Raspberry & Apple Soft Oaty Bars
# 1      557746                      Organix Carrot Cake Oaty Bars
# 2       32062                           Aptamil 2 Follow On Milk
# 3      767801                               Essential Baby Wipes
# 4      514054                           Organix Apple Rice Cakes
# ...       ...                                                ...
# 16060   85201                                    Essential Leeks
# 16061  461285      Cooks' Ingredients Chargrilled Peppers in Oil
# 16062  539814  Cooks' Ingredients Frozen Herby Chimichurri Po...
# 16063  589503               Cooks' Ingredients Artichokes in Oil
# 16064  723407   Cooks' Ingredients Frozen Stir Fry Vegetable Mix
#
#                  offer-description  is-on-offer
# 0                             None            0
# 1                             None            0
# 2                             None            0
# 3                             None            0
# 4                             None            0
# ...                            ...          ...
# 16060                         None            0
# 16061                         None            0
# 16062  Reduced to Clear. Was £3.50            1
# 16063                         None            0
# 16064                         None            0
#
# [16065 rows x 4 columns]

# %% [markdown]
# ---

# %%
# Check that all the tables are created correctly

pd.read_sql('SELECT * FROM sqlite_master', conn).set_index('sql')
# Out:
#                                                      type        name  \
# sql
# CREATE TABLE "products" (\n"id" INTEGER,\n  "na...  table    products
# CREATE TABLE "categories" (\n"product_id" INTEG...  table  categories
# CREATE TABLE "prices" (\n"product_id" INTEGER,\...  table      prices
# CREATE TABLE "offers" (\n"product_id" INTEGER,\...  table      offers
#
#                                                       tbl_name  rootpage
# sql
# CREATE TABLE "products" (\n"id" INTEGER,\n  "na...    products         2
# CREATE TABLE "categories" (\n"product_id" INTEG...  categories       923
# CREATE TABLE "prices" (\n"product_id" INTEGER,\...      prices      1088
# CREATE TABLE "offers" (\n"product_id" INTEGER,\...      offers      1201

# %% [markdown]
# ## SOLUTION 2: MORE FORMAL KEY CONSTRAINTS (more complex but ideal)
#
# The way to create the data frames that will eventually populate the database is the same as before. The difference is that we will now create the database schema with primary and foreign keys.
#
# Therefore, we cannot use the `if_exists='replace'` parameter in the `to_sql` method. Otherwise, we will just be creating new tables every time we run the code.

# %%
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: ipython in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython-sql) (9.8.0)
# Collecting sqlalchemy>=2.0 (from ipython-sql)
#   Downloading sqlalchemy-2.0.46-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting greenlet>=1 (from sqlalchemy>=2.0->ipython-sql)
#   Downloading greenlet-3.3.2-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\Oviya S\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\Oviya S\AppData\Roaming\Python\Python313\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading sqlalchemy-2.0.46-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 915.2 kB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.3 MB/s  0:00:01
# Downloading greenlet-3.3.2-cp313-cp313-win_amd64.whl (230 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Installing collected packages: ipython-genutils, sqlparse, prettytable, greenlet, sqlalchemy, ipython-sql
#
#    ------------- -------------------------- 2/6 [prettytable]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    ---------------------------------------- 6/6 [ipython-sql]
#
# Successfully installed greenlet-3.3.2 ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.17.0 sqlalchemy-2.0.46 sqlparse-0.5.5

# %%
# %load_ext sql

# %%
# For this I'd rather use the jupysql package
# %sql sqlite:///../data/supermarket.db --alias supermarket

# %%
# %%sql
#
# -- RECREATE THE products TABLE
#
# DROP TABLE IF EXISTS products;
#
# CREATE TABLE "products" (
#  "id" INTEGER PRIMARY KEY,
#  "name" VARCHAR(100),
#  "size" VARCHAR(30),
#  "page" VARCHAR(300),
#  "image-url" VARCHAR(300),
#  "type" CHAR(1)
# );
#
# -- RECREATE THE categories TABLE
#
# DROP TABLE IF EXISTS categories;
#
# CREATE TABLE "categories" (
#  "product_id" INTEGER,
#  "name" VARCHAR(50),
#  PRIMARY KEY ("product_id", "name"),
#  FOREIGN KEY ("product_id") REFERENCES "products" ("id")
# );
#
# -- RECREATE THE prices TABLE
#
# DROP TABLE IF EXISTS prices;
#
# CREATE TABLE "prices" (
#  "product_id" INTEGER,
#  "item-price" REAL,
#  "price-per-unit" TEXT,
#   FOREIGN KEY ("product_id") REFERENCES "products" ("id")
# );
#
# -- RECREATE THE offers TABLE
#
# DROP TABLE IF EXISTS offers;
#
# CREATE TABLE "offers" (
#   "product_id" INTEGER,
#   "offer-description" TEXT,
#   FOREIGN KEY ("product_id") REFERENCES "products" ("id")
# )
# Out:
#  * sqlite:///../data/supermarket.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# **Populate the database**
#
# When we try to populate the database, we get an error saying that some ids are duplicated!!
#
# This is, of course, annoying because we now have to fix the problem but good because otherwise, we would have inserted the data into the database with duplicate ids.

# %%
products.to_sql('products', conn, if_exists='append', index=False)
# Out:
# 16065

# %%
# Investigate it

# What are the duplicated ids?
duplicated_ids = products['id'][products['id'].duplicated()].tolist()

# Get the products with the duplicated ids
products[products['id'].isin(duplicated_ids)].sort_values('id')[['id', 'name', 'size']]
# Out:
#           id                                               name  \
# 204    67459                     No.1 Royal Deeside Still Water
# 48     67459                                                NaN
# 49     69460                                                NaN
# 340    69460                     Waitrose Pineapple Fruit Juice
# 48     85201                                                NaN
# 35     85201                                    Essential Leeks
# 45     85247                              Essential Cauliflower
# 48     85247                                                NaN
# 4      85513                              Duchy Organic Carrots
# 49     85513                                                NaN
# 49     86535                                                NaN
# 46     86535                      Waitrose Cherry Vine Tomatoes
# 48    522314                                                NaN
# 1962  522314  Waitrose Red Leicester Cheese & Sriracha Burge...
# 24    522601                                                NaN
# 25    522601             Essential Pedal Bin Liners Tie Handles
# 48    722909                                                NaN
# 723   722909                  John Lewis Bumble Bee Napkin 33cm
# 49    750319                                                NaN
# 2008  750319          Waitrose 2 Lemon & Lime Daisy Cheesecakes
#
#                        size
# 204                   750ml
# 48                      NaN
# 49                      NaN
# 340                  1litre
# 48                      NaN
# 35    Typical weight 0.21kg
# 45                     Each
# 48                      NaN
# 4                      650g
# 49                      NaN
# 49                      NaN
# 46                     270g
# 48                      NaN
# 1962                   140g
# 24                      NaN
# 25                      30s
# 48                      NaN
# 723                     20s
# 49                      NaN
# 2008                  2x76g

# %% [markdown]
# This error is somewhat easy to fix! The duplicated entries are essentially **scraping errors**. We can just drop those that contain NaN values in the `name` column.

# %%
# Drop the rows with NaN values in the `name` column
products = products.dropna(subset=['name'])

# %% [markdown]
# Try again:

# %%
products.to_sql('products', conn, if_exists='append', index=False)
# Out:
# 16054

# %% [markdown]
# IT WORKED!

# %% [markdown]
# **Add the categories table**

# %%
categories.to_sql('categories', conn, if_exists='append', index=False)
# Out:
# 25377

# %% [markdown]
# **Add the `prices` table to the database**

# %%
prices.to_sql('prices', conn, if_exists='append', index=False)
# Out:
# 16065

# %% [markdown]
# **Add the `offers` table to the database**

# %%
offers.to_sql('offers', conn, if_exists='append', index=False)
# Out:
# 4656

# %% [markdown]
# ✅ AND WE'RE DONE! WE MADE SURE THAT EVERYTHING IS IN THE DATABASE AND THAT THE DATA IS CONSISTENT.
